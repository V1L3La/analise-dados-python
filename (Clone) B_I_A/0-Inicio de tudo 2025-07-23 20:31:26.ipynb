# %%
print("Olá, mundo!")

# %%
nome = "Andreia" # variável do tipo string
idade = 30 # variável do tipo inteiro
print (nome)
print (idade)

# %%
nome = "Andreia"  # variável do tipo string
idade = 30        # variável do tipo inteiro
print (nome)
print (idade)
